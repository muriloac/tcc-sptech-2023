# %%
import visualize_prediction as V

import pandas as pd
import seaborn as sns

import warnings
warnings.filterwarnings('ignore')

# %%
STARTER_IMAGES=False
PATH_TO_IMAGES = "./images/"

# %%
PATH_TO_MODEL = "trained-model/checkpoint"

# %%
LABEL="Pneumonia"

# %%
POSITIVE_FINDINGS_ONLY=True

# %%
dataloader,model= V.load_data(PATH_TO_IMAGES,LABEL,PATH_TO_MODEL,POSITIVE_FINDINGS_ONLY,STARTER_IMAGES)
print("Casos para revisão:")
print(len(dataloader))
# Out:
# Casos para revisão:
# 260

# %%
preds=V.show_next(dataloader,model, LABEL)
print("Predições:")
preds
# Out:
# Predições:
#                    Probabilidade Prevista  Verdadeiro Positivo
# Achado
# Atelectasis                         0.418                 True
# Infiltration                        0.163                 True
# Effusion                            0.071                False
# Nodule                              0.062                False
# Pneumothorax                        0.022                False
# Pneumonia                           0.020                 True
# Consolidation                       0.018                False
# Mass                                0.017                False
# Pleural_Thickening                  0.012                False
# Edema                               0.011                False
# Fibrosis                            0.008                False
# Cardiomegaly                        0.003                False
# Emphysema                           0.003                False
# Hernia                              0.003                False
